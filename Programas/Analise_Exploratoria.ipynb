# %%
from pandas import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
jogo = pd.read_csv(r"C:\Users\rodli\PycharmProjects\fluzao\static\backup\previsao.csv", index_col=None, sep=',')

# %%
print(jogo.head(10))
# Out:
#    cod_adv  cod_estadio  mandante  cod_juiz  cod_campeonato  res_flu  res_adv  \
# 0       24           31         1        32              16        8        0
# 1       25           31         1        32              16        0        3
# 2       26           25         1        33              17        3        1
# 3       25           31         1      1402              17        1        3
# 4       27           21         1        34             556        0        0
# 5       28           21         1        35             556        2        1
# 6       29           21         1        35             556        3        0
# 7       25           31         1      1403              17        2        2
# 8      663           25         1      1404              17        3        2
# 9       26           25         1        33              18        2        1
#
#    cod_tec        data  cod_tecnico_adv   campres estado    pais  \
# ...

# %%
jogo.describe()
# Out:
#            cod_adv  cod_estadio     mandante     cod_juiz  cod_campeonato  \
# count  5954.000000  5954.000000  5954.000000  5954.000000     5954.000000
# mean    173.529560   111.056601     0.569701   499.125798      366.830030
# std     181.625708   151.678887     0.495160   386.497308      212.509468
# min      24.000000    20.000000     0.000000    32.000000       16.000000
# 25%      49.000000    40.000000     0.000000   231.000000      194.000000
# 50%      87.000000    55.000000     1.000000   361.000000      331.000000
# 75%     230.750000   102.000000     1.000000   689.750000      567.000000
# max     788.000000   790.000000     1.000000  1514.000000      801.000000
#
#            res_flu      res_adv      cod_tec  cod_tecnico_adv       campres
# count  5954.000000  5954.000000  5954.000000      5954.000000  5.954000e+03
# mean      1.897044     1.200705    46.486396       469.057272  1.000002e+07
# ...

# %%
jogo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5954 entries, 0 to 5953
# Data columns (total 15 columns):
# cod_adv            5954 non-null int64
# cod_estadio        5954 non-null int64
# mandante           5954 non-null int64
# cod_juiz           5954 non-null int64
# cod_campeonato     5954 non-null int64
# res_flu            5954 non-null int64
# res_adv            5954 non-null int64
# cod_tec            5954 non-null int64
# data               5954 non-null object
# cod_tecnico_adv    5954 non-null int64
# campres            5954 non-null int64
# estado             5954 non-null object
# pais               5954 non-null object
# nome_camp          5954 non-null object
# resultado          5954 non-null object
# dtypes: int64(10), object(5)
# memory usage: 697.9+ KB

# %%
plt.scatter(jogo['resultado'], jogo['cod_adv'])
plt.title("Relação de adversários e resultado")
plt.xlabel("Resultado")
plt.ylabel("Adversário")
# Out:
# Text(0, 0.5, 'Adversário')

# %%
sns.pairplot(jogo)

# %%
sns.heatmap(jogo.corr(), annot=True, cmap='RdBu', vmin=1, vmax=1);
